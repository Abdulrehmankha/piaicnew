# %%
print("----------------------------------Abdul Rehman Khan-----------------------")
print("-------------------------------Assignment No # 02------------------------")
print("---------------------------------Task No # 1-----------------------")
items = float(input("enter no items"));
print items
no_item = int(items)
print("your total price is for each item is $200 and you enter items is ",no_item)
print("thank's for Shopping!")

print("---------------------------------------Assignment No # 02 ------------------")
print("--------------------------------------Task No # 2-----------------------")
year_of_joining = int(input("\t enter your joining year :\t\t"))
current_year = int(input("\t enter your current year: \t\t"))
services = current_year - year_of_joining
print ("congratulations! you give services")
print services

print("---------------------------------------Assignment No # 02 ------------------")
print("--------------------------------------Task No # 3-----------------------")
f_temp = int (input("enter temperature in fahrenheit :"))
c= int ( (5/9)*(f_temp-32) )
print("temperature in celsius is :")
print c

print("---------------------------------------Assignment No # 02 ------------------")
print("--------------------------------------Task No # 4-----------------------")
print ("\t\t Simple marksheet \t\t")
a = int(input("enter marks of physics: "))
b = int(input("enter marks of maths: "))
c = int(input("enter marks of english: "))
d = int(input("enter marks of urdu: "))
e = int(input("enter marks of islamiat: "))
g = int(input("enter marks of statistics: "))
f = (a+b+c+d+e+g)/6
if (f>=90):
    print("\t\t A.one grade \t you are passed!\t\n")
    print("\n total percentage is:")
    print f
elif (f>=80):
    print ("\t\t A grade \t you are passed!\t\n")
    print("\n total percentage is:")
    print f
elif (f>=70):
    print ("\t\t B grade \t you are passed!\t\n")
    print("\n total percentage is:")
    print f
elif (f>=60):
    print ("\t\t C grade \t you are passed!\t\n")
    print("\n total percentage is:")
    print f
elif (f>=55):
    print ("\t\t D grade \t you are passed!\t\n")
    print("\n total percentage is:")
    print f
elif (f>=50):
    print ("\t\t E grade \t you are promoted!\t\n  ")
    print("\n total percentage is:")
    print f
    
else:
    print ("\t\t F grade \t you are failed!\t\n ")
    print("\n total percentage is:")
    print f
# Out:
# ----------------------------------Abdul Rehman Khan-----------------------
# -------------------------------Assignment No # 02------------------------
# ---------------------------------Task No # 1-----------------------
# enter no items23
# 23.0
# ('your total price is for each item is $200 and you enter items is ', 23)
# thank's for Shopping!
# ---------------------------------------Assignment No # 02 ------------------
# --------------------------------------Task No # 2-----------------------
# 	 enter your joining year :		2000
# 	 enter your current year: 		2005
# congratulations! you give services
# 5
# ---------------------------------------Assignment No # 02 ------------------
# --------------------------------------Task No # 3-----------------------
# enter temperature in fahrenheit :56.8
# temperature in celsius is :
# 0
# ---------------------------------------Assignment No # 02 ------------------
# --------------------------------------Task No # 4-----------------------
# ...
